# %%
import re
import pandas as pd
import json
import datetime
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# # Structure Raw Data

# %% [markdown]
# ### Tik Tok

# %%
with open("./data/tokboard_record.json", "r") as f:
    tiktok_charts = json.load(f)

# %%
# charting TikTok sounds 
pre_df = {}
for month in tiktok_charts:
    chart = tiktok_charts[month]
    for rank in chart:
        song = chart[rank]
        title = song['title'].lower()
        user = song['artist'].lower()
        if (title, user) not in pre_df:
            pre_df[(title, user)] = {month: int(rank)}
        else:
            pre_df[(title, user)][month] = int(rank)
            
tok_charts_df = pd.DataFrame(pre_df).transpose()
tok_charts_df.index.set_names(["Title", "Artist"], inplace=True)

# %%
num_songs = len(tok_charts_df)
num_artists = len(set(tok_charts_df.index.get_level_values("Artist")))
print("Tik Tok Trending Sounds:")
print("---")
print(num_songs, "total songs")
print(num_artists, "unique accounts")
print("\n")
# Out:
# Tik Tok Trending Sounds:
# ---
# 1890 total songs
# 1703 unique accounts

# %% [markdown]
# ### Spotify
# - Spotify Viral 50 (Global)
# - Spotify Top 200 (Global)
# - Spotify Viral 50 (USA)
# - Spotify T0p 200 (USa)

# %%
# Global Viral 50
with open("./data/global_viral_50.json", "r") as f:
    spot_v50 = json.load(f)

# %%
# USA Viral 50
with open("./data/usa_viral_50.json", "r") as f:
    spot_v50_usa = json.load(f)

# %%
# Global Top 200
with open("./data/global_top_200.json", "r") as f:
    spot_top200 = json.load(f)

# %%
# USA Top 200
with open("./data/usa_top_200.json", "r") as f:
    spot_top200_usa = json.load(f)

# %%
# charting spotify songs history
def get_spot_df(all_charts):
    pre_df = {}
    for week in all_charts:
        chart = all_charts[week]
        for rank in chart:
            song = chart[rank]
            title = song['title'].lower()
            title = re.sub(r"&amp;", "&", title)
            artist = song['artist'][3:].lower()
            artist = re.sub(r"&amp;", "&", artist)
            if (title, artist) not in pre_df:
                pre_df[(title, artist)] = {week[:10]: int(rank) + 1}
            else:
                pre_df[(title, artist)][week[:10]] = int(rank) + 1
            
    df = pd.DataFrame(pre_df).transpose()
    df.index.set_names(["Title", "Artist"], inplace=True)
    return df

spot_v50_df = get_spot_df(spot_v50)
spot_top200_df = get_spot_df(spot_top200)
spot_v50_usa_df = get_spot_df(spot_v50_usa)
spot_top200_usa_df = get_spot_df(spot_top200_usa)

# %%
num_songs = len(spot_v50_df)
num_artists = len(set(spot_v50_df.index.get_level_values("Artist")))
print("Spotify Viral 50 (Global):")
print("---")
print(num_songs, "total songs")
print(num_artists, "unique artists")
print("\n")

num_songs = len(spot_top200_df)
num_artists = len(set(spot_top200_df.index.get_level_values("Artist")))
print("Spotify Top 200 (Global):")
print("---")
print(num_songs, "total songs")
print(num_artists, "unique artists")
print("\n")

num_songs = len(spot_v50_usa_df)
num_artists = len(set(spot_v50_usa_df.index.get_level_values("Artist")))
print("Spotify Viral 50 (USA):")
# print("---")
print(num_songs, "total songs")
print(num_artists, "unique artists")
print("\n")

num_songs = len(spot_top200_usa_df)
num_artists = len(set(spot_top200_usa_df.index.get_level_values("Artist")))
print("Spotify Top 200(Global):")
print("---")
print(num_songs, "total songs")
print(num_artists, "unique artists")
print("\n")
# Out:
# Spotify Viral 50 (Global):
# ---
# 2242 total songs
# 1744 unique artists
#
#
# Spotify Top 200 (Global):
# ---
# 2516 total songs
# 1061 unique artists
#
#
# Spotify Viral 50 (USA):
# 2395 total songs
# 1655 unique artists
#
#
# Spotify Top 200(Global):
# ---
# 2990 total songs
# 859 unique artists

# %% [markdown]
# ### Billboard
# - Billboard Top 200
# - Billboard Hot 100

# %%
with open("./data/bilboard_200.json", "r") as f:
    bil_200 = json.load(f)

# %%
with open("./data/bilboard_hot_100.json", "r") as f:
    bil_h100 = json.load(f)

# %%
# charting billboard history

def get_bil_df(bil):
    pre_df = {}
    for week in bil:        
        chart = bil[week]
        for rank in chart:
            song = chart[rank]
            title = song['song'].lower()
            title = re.sub(r"&amp;", "&", title)
            artist = song['artist'].lower()
            artist = re.sub(r"&amp;", "&", artist)
            if (title, artist) not in pre_df:
                    pre_df[(title, artist)] = {week[:10]: int(rank) + 1}
            else:
                pre_df[(title, artist)][week[:10]] = int(rank) + 1
    df = pd.DataFrame(pre_df).transpose()
    df.index.set_names(["Title", "Artist"], inplace=True)
    return df

bil_200_df = get_bil_df(bil_200)
bil_h100_df = get_bil_df(bil_h100)

# %%
num_songs = len(bil_200_df)
num_artists = len(set(bil_200_df.index.get_level_values("Artist")))
print("Billboard Top 200:")
print("---")
print(num_songs, "total songs")
print(num_artists, "unique artists")
print("\n")

num_songs = len(bil_h100_df)
num_artists = len(set(bil_h100_df.index.get_level_values("Artist")))
print("Billboard Hot 100:")
print("---")
print(num_songs, "total songs")
print(num_artists, "unique artists")
print("\n")
# Out:
# Billboard Top 200:
# ---
# 1975 total songs
# 1201 unique artists
#
#
# Billboard Hot 100:
# ---
# 1757 total songs
# 936 unique artists

# %% [markdown]
# # Merge Songs From All Platforms

# %%
all_songs = set(tok_charts_df.index)
all_songs = all_songs.union(set(spot_v50_df.index))
all_songs = all_songs.union(set(spot_top200_df.index))
all_songs = all_songs.union(set(spot_v50_usa_df.index))
all_songs = all_songs.union(set(spot_top200_usa_df.index))
all_songs = all_songs.union(set(bil_200_df.index))
all_songs = all_songs.union(set(bil_h100_df.index))

zip([spot_v50_df, spot_top200_df], ["spot_v50", "spot_200"])
charts = [spot_v50_df, spot_top200_df, spot_v50_usa_df, spot_top200_usa_df, bil_200_df, bil_h100_df]
names = ["spot_v50", "spot_top200", "usa_v50", "usa_top200", "bil_200", "bil_h100"]

big_bucks = pd.DataFrame(index=all_songs)

for idx in big_bucks.index:
    if idx in tok_charts_df.index:
        tok = tok_charts_df.loc[idx[0],idx[1]].dropna()
        big_bucks.at[idx, "tok_first_date"] = datetime.datetime.strptime(tok.index[0], "%B-%Y").strftime("%Y-%m")
        big_bucks.at[idx, "tok_first_rank"] = tok[0]
        tok = tok.sort_values()
        big_bucks.at[idx, "tok_best_date"] = datetime.datetime.strptime(tok.index[0], "%B-%Y").strftime("%Y-%m")
        big_bucks.at[idx, "tok_best_rank"] = tok[0]
    
    
    for chart, name in zip(charts, names):
        if idx in chart.index:
            spot = chart.loc[idx[0],idx[1]].dropna().sort_values()
            first_date = spot.index.sort_values()[0]
            first_rank = spot[first_date]
            big_bucks.at[idx, f"{name}_first_date"] = first_date[:7]
            big_bucks.at[idx, f"{name}_first_rank"] = first_rank
            big_bucks.at[idx, f"{name}_best_date"] = spot.index[0]
            big_bucks.at[idx, f"{name}_best_rank"] = spot[0]    
big_bucks = big_bucks.drop(("", ""))
big_bucks.index.set_names(["Title", "Artist"], inplace=True)

# %%
# Replace empty artist names
all_index = big_bucks.index.tolist()
titles = []
artists = []
for i, value in enumerate(all_index):
    titles.append(value[0])
    if value[1] == "":
        artists.append("-")
    else:
        artists.append(value[1])
big_bucks = big_bucks.set_index([titles, artists])
big_bucks.index.set_names(["Title", "Artist"], inplace=True)

# %%
big_bucks.to_csv("song_library.csv")

# %% [markdown]
# # Retrieve Song Data

# %%
CLIENT_ID = "69200cfc38774a4394c7bc17911d0c08"
CLIENT_SECRET = "6c5f36f3da3e4e699ebc7ba59d3d9792"
auth_manager= spotipy.oauth2.SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)#, redirect_uri=REDIRECT_URI, scope='playlist-modify-public, playlist-modify-private')
sp = spotipy.Spotify(client_credentials_manager=auth_manager)

# %%
def parse_artist(results):
    artist_id = results['id']
    pop = results['popularity']
    followers = results['followers']['total']
    genres = results['genres']
    related = []
    for r in sp.artist_related_artists(artist_id)['artists']:
        related.append((r['name'], r['id'])) 
    return {"artist_id": artist_id, 
            "artist_popularity": pop, 
            "followers": followers, 
            "genres": genres, 
            "related": related, 
            "songs": {}}

def parse_song(song_results):
    release_date = song['album']['release_date']
    duration = song['duration_ms']
    song_popularity = song['popularity']
    song_id = song['id']
    audio_feats = sp.audio_features(song_id)[0]
    return {"song_id": song_id, 
            "release_date": release_date, 
            "duration": duration, 
            "song_popularity": song_popularity, 
            "audio_feats": audio_feats}

artist_info = {}
missed = []
for i, (title, artist) in enumerate(big_bucks.index):
#     print(title, artist)
    if artist not in artist_info and artist != "":
        results = sp.search(q=artist, type="artist", limit=1)['artists']['items']
        if len(results) > 0:
            artist_info[artist] = parse_artist(results[0])
    
    song = sp.search(q=f"{title} artist:{artist}", type="track")['tracks']['items']
    temp = {}
    if len(song) == 0:
        song = sp.search(q=title, type="track")['tracks']['items']
    if len(song) > 0:
        song = song[0]
        temp = parse_song(song)
        
        if artist not in artist_info:
            artist_id = song['artists'][0]['id']
            artist_results = sp.artist(artist_id)
            artist_info[artist] = parse_artist(artist_results)
            
    # still no results after 2 tries
    if artist not in artist_info:
        artist_info[artist] = {"songs": {}}
        missed.append((title, artist))
        print(f"Missed: {artist}")
    
    artist_info[artist]["songs"][title] = temp
    
    if i % 100 == 0:
        with open("artist_song_info.csv", "w") as f:
            json.dump(artist_info, f)
            
with open("artist_song_info.csv", "w") as f:
    json.dump(artist_info, f)
# Out:
# Missed: lv.01 napkins
# Missed: iamkhizarkhan
# Missed: rajput banna
# Missed: vunnypubgm
# Missed: jeytee4u
# Missed: quantumwolf115
# Missed: mike moonnight &amp; dm'boys
# Missed: status boy ammu_87
# Missed: .gacha._.cartoons
# Missed: wowbrey
# Missed: goalsounds
# Missed: anmol1908
# Missed: 岩谷竜宇 《りょー🗽》
# Missed: mind your business ❤️
# Missed: maddiefckinsmokez
# Missed: sounds420
# Missed: heyjacxb
# Missed: di_ana_ss
# Missed: elizabeth_chetwynd
# Missed: ravecentral
# Missed: jadenhasnoclout
# Missed: zachfromdisney
# Missed: bhinda aujla &amp; bobby layal feat. sunny boy
# Missed: èsco upp🗣
# Missed: quincy boykins🐺🌪
# Missed: _ucil👑
# Missed: moolesh_bheel88
# Missed: thedylanmiller
# Missed: picoslander is a sussy baka
# Missed: stonerreacts🍃😏
# Missed: sm0l.ash
# Missed: 👑 h a r s h 👑
# Missed: ashi khanna
# Missed: ꧁justin7u7mike꧂
# Missed: bhavik_dhanak
# Missed: amzorcen
# Missed: øceancollab
# Missed: dcfreestyle_official
# Missed: call me jony 🤓
# Missed: robirawks_
# Missed: rishhpgautam
# Missed: rauw alejandro, j balvin
# Missed: lil.st1nky
# Missed: elizabeth the first
# Missed: akashandhale97
# Missed: quality control, layton greene
# Missed: nsfwsoup
# Missed: adamczyczek
# Missed: teresa jack
# Missed: iravneetsingh
# Missed: nolimitprince
# Missed: djtvmpo
# Missed: kevindaveprod
# Missed: lakshya, the begraj &amp; md kd
# Missed: andreaasensii_
# Missed: 𝚊𝚎𝚜𝚝𝚑𝚎𝚝𝚒𝚌 𝙸𝚌𝚘𝚗𝚜
# Missed: slander, dylan matthew
# Missed: christopher colarusso
# Missed: matt randone
# Missed: videos_edits12
# Missed: evelynleticia
# Missed: varoon ramesh
# Missed: nextyoungin &amp; ppcocaine
# Missed: 🌺밍들🌺
# Missed: kulsarawat
# Missed: i am not sza.
# Missed: sudipa biswas
# Missed: sid chauhan bmachine
# Missed: tumbling.sunflowers71
# Missed: biblegrrl
# Missed: pawans_offecial_555
# Missed: vin._.u06
# Missed: sohail faizan
# Missed: iamtherealtaj
# Missed: nookkoon
# Missed: chisa2122
# Missed: lavidadetomas
# Missed: kashi_ram_prajapat
# Missed: user156803782
# Missed: gang13 official
# Missed: choijae96
# Missed: riahchu3
# Missed: katalyst_224
# Missed: itsjessmena
# Missed: 👶
# Missed: bhushan2545👑
# Missed: daddysmemesauce
# Missed: isla mcmillan✨
# Missed: talia schulhof
# Missed: mingaling 2.0
# Missed: wafelnaise
# Missed: salmansllmn1
# Missed: itsundos
# Missed: bixxybop
# Missed: ไอเตี้ยน่ารักก🥀💗
# Missed: kingvader
# Missed: 💃🏿
# Missed: adamohmusic
# Missed: musicag_ig
# Missed: autumnaudioz
# Missed: itzmilpops
# Missed:
# Missed: imjakelawson
# Missed: vashamarousia
# Missed: amarjit rajput
# Missed: aka_your_girl
# Missed: arjun janya &amp; vijay prakash
# Missed: adolf_90
# Missed: tahiti_jade
# Missed: probsurdad
# Missed: faizullahfaiz1
# Missed: i'm. jatain
# Missed: fl1ntwater
# Missed: siddharth lokhande
# Missed: shivamgrover452
# Missed: iamtiagz
# Missed: абажаб😈
# Missed: bugattispaceship
# Missed: tysm 300k &lt;3
# Missed: 🌷쥬현🌷
# Missed: static2.0😄
# Missed: shelovesdarrion
# Missed: dnyandeepkadam
# Missed: certified barb
# Missed: _dhruvit_soni
# Missed: arrisha smith
# Missed: my heart stays real
# Missed: ryi&lt;3
# Missed: ktm 乂তুফান///¥ ₮
# Missed: kiara.padi
# Missed: ayaan.ugreja
# Missed: song writer m ali
# Missed: muddasirkhan003
# Missed: dj cummerbund
# Missed: ohrobin
# Missed: sibiduantiktok
# Missed: lerushka👐🏼
# Missed: 💜the🌀tiktok🌀boy💜
# Missed: ponciklendin
# Missed: penelope dolce
# Missed: tanner3671
# Missed: 🎵anti.audios🎵
# Missed: blaineadamshere
# Missed: scary spice
# Missed: brandy running and crying
# Missed: weird genius, sara fajira
# Missed: ånnabellëmåriaxx
# Missed: maximo lenis
# Missed: https.sav
# Missed: tandelhitesh01
# Missed: traptology
# Missed: suneysounds
# Missed: trevorduvenage
# Missed: mõñìķã§ãh
# Missed: madison elliott
# Missed: ⭐️✨🌻
# Missed: myeyesburn
# Missed:  🄰🄻🄱🅁🄴🅆 🦊
# Missed: picklepatty_39
# Missed: dafaatmja
# Missed: paravi (par-o-vee) 💖🌻🦋✨
# Missed: joselynv_
# Missed: ສອນໄຊ ບ່າວລາວ
# Missed: tushararoraofficial
# Missed: beyonce & various artists
# Missed: vinny rowdy baby😎
# Missed: mendel &amp; judah abehsera
# Missed: sushmita_shrestha
# Missed: lamadabe
# Missed: itsjustjakieg
# Missed: muhammed alarithy
# Missed: michael luthra❤
# Missed: est.mattiav2
# Missed: 𝘮𝘺𝘧𝘦𝘦𝘭𝘪𝘯𝘨𝘴
# Missed: sona sona solanki
# Missed: darpanshahds
# Missed: 🚶🏽
# Missed: sheriff_alex
# Missed: _dxddy_bxlla_
# Missed: katelynlapid
# Missed: hiralp02979
# Missed: radhasingh188
# Missed: 💥flash:warning⚠️
# Missed: kamal bishnoi
# Missed: hi my name is nsx
# Missed: calegoes
# Missed: 🍃.
# Missed: piyapong poynok
# Missed: calebjaxin
# Missed: ajayhooda1984
# Missed: sphintuscarmen
# Missed: रवीना वर्मा
# Missed: kartashow/мари краймбрери
# Missed: waikiki_fields
# Missed: shekhawat anand
# Missed: भोले का लाड़ला ❤️👑
# Missed: sporttothin
# Missed: luis fonsi &amp; daddy yankee
# Missed: 백동욱🌈
# Missed: тне агснivе
# Missed: favsoundds
# Missed:  bollywoodtunez
# Missed: anotherlogi
# Missed: 雅利安 😁
# Missed: sydneybourne_
# Missed: onlyy.oceaan
# Missed: sherawatshivam
# Missed: 🥴
# Missed: mr_sharukh08
# Missed: eastisup
# Missed: arun kawde
# Missed: badanmall
# Missed: 𝒮𝓉𝒶𝓇𝒸𝑜𝓊𝓇𝓉 ℳ𝒶𝓁𝓁
# Missed: 😎👑⭐️🪐🤷🏽‍♀️✨
# Missed: realerreacts0
# Missed: bakugou’s c*m jar🚪
# Missed: shetdawg
# Missed: jason derulo &amp; snoop dogg
# Missed: fukru123
# Missed: jiro morato ⍟
# Missed: hidjabtagykyz
# Missed: 💘ᴏʀʙɪᴛ✨ʜɪᴛs💦
# Missed: unicorn shart❤️
# Missed: fjj_gurll_._♡
# Missed: xxcoleslawxx
# Missed: ryan prevedel
# Missed: omgdats...c
# Missed: thank you guys for 3k🙏🏽
# Missed: maahi sahu
# Missed: mr.ajjunegi
# Missed: alon uwu
# Missed: faizan_______patel
# Missed: simjim6627
# Missed: burned.toast420
# Missed: hollie marsh🤍
# Missed: _.editedsounds
# Missed: bliberry_p
# Missed: amaira shahnawaz
# Missed: ᔕiᑎeᗩᗪ
# Missed: whozmanzzz
# Missed: rh music, eduardo luzquiños
# Missed: qthunter
# Missed: deepakbhardwaj246
# Missed: jm yrreverre
# Missed: neelpatelofficial
# Missed: princess mariyam 💞
# Missed: emann_hh
# Missed: zy🔥h21_👑
# Missed: jaden hannon
# Missed: king.jodey
# Missed: zachoverweg
# Missed: abhay143
# Missed: tyananana
# Missed: ｓｔａｙ　ｈｙｄｒａｔｅｄ　緯俺な
# Missed: jaedengomez
# Missed: rimhussein
# Missed: deepak_sharma_actr
# Missed: cashbouvier
# Missed: xoprinceali
# Missed: _otaku_talks
# Missed: sushma  sushi kumain
# Missed: visualz by mariee
# Missed: 💙김스테파니헤리💙
# Missed: lastmanstanley
# Missed: lucaselvis
# Missed: 🎄🎄🎄
# Missed: robbyㅤㅤsintenㅤ??
# Missed: ishan bagga
# Missed: deepanshu balyan
# Missed: coenbeauty
# Missed: bxtchsounds.s
# Missed: michael pepito
# Missed: alexis mcclellan
# Missed: galtiano11
# Missed: whozmanzz
# Missed: marlon pendleton
# Missed: visan786
# Missed: aevans74
# Missed: squishy.nut
# Missed: ᴡᴀʀᴀɪɢᴏɴᴀqᴏʀɪ_ᴇᴅɪᴛᴢ
# Missed: 🐷きょっちゃん🐽
# Missed: @sosyo_drink_najim
# Missed: xforgotten_audiosx
# Missed: faisalmaxx
# Missed: lulbabyynelii
# Missed: tysm for 100k💗💗
# Missed: ldrethegiant
# Missed: thtlighskin
# Missed: user20862740
# Missed: anebratli_
# Missed: presleywalker
# Missed: flexgod.henry
# Missed: ૮₍ ´𖦹 ˕ ×` ₎ა
# Missed: fylertunke
# Missed: :/
# Missed: bamthedancer
# Missed: 🔥jio tanu_09🔥
# Missed: zaafarshaikh2
# Missed: bigyai seehalad
# Missed: tik toker
# Missed: vhs._aesthetics
# Missed: iamcarlos__
# Missed: {નટખટ કાનુડૉ }
# Missed: mahak hamid
# Missed: devil00143
# Missed: kaygon__

# %%
artist_info.keys()
# Out:
# dict_keys(['michael sweet', 'janati.sarah', 'camilo', 'avril lavigne', 'cardi b', 'kali uchis', 'bailey zimmerman', 'lil baby', 'vianea😁', 'mac miller', 'yelawolf', 'kostromin', 'dermot kennedy', 'anuel aa, farruko, zion', 'swizz beatz', 'louis armstrong & friends', 'alesso', 'the citizens of halloween', 'meek mill', 'pinkfong', 'the chicks', 'lennon stella', 'luciano', 'chema rivas', 'chicago', 'natanael cano', 'feby putri', 'the chainsmokers featuring kelsea ballerini', 'olivermoy', 'trippie redd', 'mike will made-it', 'queen naija', 'olivia rodrigo, joshua bassett', 'lauana prado, maiara & maraisa', 'ariana grande', 'kyson', 'tiagz', 'tory lanez', 'lv.01 napkins', 'flipp dinero', 'iamkhizarkhan', 'ricky rich, aram mafia', 'carrie underwood & john legend', 'youngboy never broke again', 'lil durk', 'ray j', 'ill wayno, holla fyesixwun', 'disturbed', 'matutev', 'mooski', 'asking alexandria', 'halsey, suga, bts', 'snoh aalegra', 'sebastian yatra, myke towers', 'kid cudi', 'judy garland', 'luh kel', 'bazzi', 'raullcabello2', 'andy mineo, lecrae', 'leslie grace, noriel', 'taylor swift', 'aminé', 'troyboi', 'frank ocean', 'gunna featuring lil baby', 'deshawn🤩🥶', 'rajput banna', 'kodak black', 'badflower', '5 seconds of summer', 'pop smoke', 'rbd, anahí, dulce maría, maite perroni, christian chávez, christopher von uckermann, alfonso herrera', 'kehlani', 'drake', 'benny blanco', 'gangga', 'lil nas x', 'elias monkbel', 'city girls', 'h.e.r.', 'eik octobre', 'itsabigbigsecret', 'spotemgottem, pooh shiesty', 'ashnikko', 'vegedream', 'gusttavo lima', 'ramz', 'twenty one pilots', 'rex orange county', 'schoolboy q', 'nle choppa', 'chocquibtown, zion & lennox, farruko', 'getter jaani', 'sabrina carpenter', 'dmx', 'os barões da pisadinha', 'akhil sachdeva, tulsi kumar', 'sean stemaly', 'the neighbourhood', 'wale', 'bankrol hayden', 'lunay, daddy yankee, bad bunny', 'sachet-parampara, parampara tandon, nora fatehi', 'tool', 'vitamin string quartet', 'the 1975', '21 savage & metro boomin featuring young thug', 'capital bra', 'enzo.cāęsc', 'king staccz', 'martin garrix, justin mylo', 'joji', 'luke combs, brooks & dunn', 'shawn mendes', 'powfu', 'city girls, doja cat', 'kesh kesh', 'vunnypubgm', 'drake featuring giveon', 'trevor daniel', '21 savage', 'jasiah', 'free nationals', 'zain.alpha', 'miley cyrus', 'japanese breakfast', 'chance the rapper', 'brantley gilbert', 'play-n-skillz, daddy yankee, zion & lennox', 'caribou', 'jeytee4u', 'sam smith', 'ryanroymusic', 'idina menzel & aurora', 'greta van fleet', 'robyn', 'rayito colombiano', 'the fray', 'sheff g', 'roddy ricch', 'julia michaels', 'mahmood', 'lin-manuel miranda, anthony ramos, daveed diggs, okieriete onaodowan, leslie odom jr., original broadway cast of hamilton', 'marco sentieri', 'x)', 'shoreline mafia', 'chase rice', 'dan + shay', 'maluma', 'hard lights, moonshine, ember island', 'pop smoke featuring lil tjay', '_madi.nicole', 'ksi', 'camille saint-saëns, philippe entremont, gaby casadesus, yo-yo ma', 'tom petty', 'paulo londra', 'lil uzi vert', 'st. paul & the broken bones', 'bad bunny', 'rich music ltd, sech, dalex, justin quiles, lenny tavárez, feid', 'loretta lynn', 'eminem featuring anderson .paak', 'vityaw', 'badbadnotgood, mf doom', 'quantumwolf115', 'kenny rogers', 'lauv', 'emman', 'kim loaiza', 'young stoner life, young thug, gunna', 'shiva, eiffel 65', 'tyga', 'offset', 'tom walker', 'anuel aa', 'dababy', 'hailee steinfeld', 'nf', 'old dominion', 'stick figure', 'king lil g', 'jordan davis', 'kris wu', 'ashe', "mike moonnight &amp; dm'boys", 'el villanord, yailin la mas viral', 'ozuna', 'status boy ammu_87', 'post malone featuring nicki minaj', 'headie one, drake', 'jonas brothers', 'juice wrld', '_._.angels._._', 'the xx', 'dean lewis', 'marshmello & halsey', 'luke bryan', 'a boogie wit da hoodie, don q, trap manny', 'ajay stephens', 'lil wayne', 'rick ross', 'j balvin', 'mimi webb', 'music hero', 'yungkash k1k', 'spotemgottem featuring pooh shiesty or dababy', 'zeynep ...

# %%
related_artists = {}
for i, artist in enumerate(artist_info):
    related = []
    if "artist_id" not in artist_info[artist]:
        related_artists[artist] = []
    else:
        artist_id = artist_info[artist]['artist_id']
        for r in sp.artist_related_artists(artist_id)['artists']:
            related.append((r['name'], r['id'])) 
        related_artists[artist] = related
        if i % 500 == 0:
            with open("related_artists.json", "w") as f:
                json.dump(related_artists, f)

with open("related_artists.json", "w") as f:
    json.dump(related_artists, f)
